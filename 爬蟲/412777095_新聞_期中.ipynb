# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 79.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 6.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# 1. 請使用scrapy套件爬取 udn.com 網站 及 另一個自選網站

# %%
#!scrapy runspider setn.py -o setn.jl #udn

# %%
#搜集和這兩個詞無關的新聞20篇-others
# !scrapy runspider udn.py -o others.jl #udn
# Out:
# 2025-05-28 13:36:36 [scrapy.utils.log] INFO: Scrapy 2.13.1 started (bot: scrapybot)
# 2025-05-28 13:36:36 [scrapy.utils.log] INFO: Versions:
# {'lxml': '5.4.0',
#  'libxml2': '2.13.8',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '24.11.0',
#  'Python': '3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]',
#  'pyOpenSSL': '24.2.1 (OpenSSL 3.3.2 3 Sep 2024)',
#  'cryptography': '43.0.3',
#  'Platform': 'Linux-6.1.123+-x86_64-with-glibc2.35'}
# 2025-05-28 13:36:36 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-05-28 13:36:36 [asyncio] DEBUG: Using selector: EpollSelector
# 2025-05-28 13:36:36 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-05-28 13:36:36 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2025-05-28 13:36:36 [scrapy.extensions.telnet] INFO: Telnet Password: bed7f6f5ac2802f3
# ...

# %%
#已修改的程式-keyword1
# !scrapy runspider udn_key-1.py -o keyword1.jl #udn
# Out:
# 2025-05-28 13:41:24 [scrapy.utils.log] INFO: Scrapy 2.13.1 started (bot: scrapybot)
# 2025-05-28 13:41:24 [scrapy.utils.log] INFO: Versions:
# {'lxml': '5.4.0',
#  'libxml2': '2.13.8',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '24.11.0',
#  'Python': '3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]',
#  'pyOpenSSL': '24.2.1 (OpenSSL 3.3.2 3 Sep 2024)',
#  'cryptography': '43.0.3',
#  'Platform': 'Linux-6.1.123+-x86_64-with-glibc2.35'}
# 2025-05-28 13:41:24 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-05-28 13:41:24 [asyncio] DEBUG: Using selector: EpollSelector
# 2025-05-28 13:41:24 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-05-28 13:41:24 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2025-05-28 13:41:24 [scrapy.extensions.telnet] INFO: Telnet Password: 4a01be8e4d0f2482
# ...

# %%
#已修改的程式-keyword2
# !scrapy runspider udn_key-2.py -o keyword2.jl #udn
# Out:
# 2025-05-28 13:44:54 [scrapy.utils.log] INFO: Scrapy 2.13.1 started (bot: scrapybot)
# 2025-05-28 13:44:54 [scrapy.utils.log] INFO: Versions:
# {'lxml': '5.4.0',
#  'libxml2': '2.13.8',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '24.11.0',
#  'Python': '3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]',
#  'pyOpenSSL': '24.2.1 (OpenSSL 3.3.2 3 Sep 2024)',
#  'cryptography': '43.0.3',
#  'Platform': 'Linux-6.1.123+-x86_64-with-glibc2.35'}
# 2025-05-28 13:44:54 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-05-28 13:44:54 [asyncio] DEBUG: Using selector: EpollSelector
# 2025-05-28 13:44:54 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-05-28 13:44:54 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2025-05-28 13:44:54 [scrapy.extensions.telnet] INFO: Telnet Password: 2b6bd31def3d5cda
# ...

# %%
#已修改的程式-keyword-兩個詞
# !scrapy runspider udn_key-3.py -o keyword.jl #udn
# Out:
# 2025-05-28 13:47:02 [scrapy.utils.log] INFO: Scrapy 2.13.1 started (bot: scrapybot)
# 2025-05-28 13:47:02 [scrapy.utils.log] INFO: Versions:
# {'lxml': '5.4.0',
#  'libxml2': '2.13.8',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '24.11.0',
#  'Python': '3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]',
#  'pyOpenSSL': '24.2.1 (OpenSSL 3.3.2 3 Sep 2024)',
#  'cryptography': '43.0.3',
#  'Platform': 'Linux-6.1.123+-x86_64-with-glibc2.35'}
# 2025-05-28 13:47:02 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-05-28 13:47:02 [asyncio] DEBUG: Using selector: EpollSelector
# 2025-05-28 13:47:02 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-05-28 13:47:02 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2025-05-28 13:47:02 [scrapy.extensions.telnet] INFO: Telnet Password: ce12e2f2ff134746
# ...

# %%
# #已修改的程式-有label
# !scrapy runspider udn_label.py -o udn_label.jl #udn
# Out:
# 2025-05-28 13:23:16 [scrapy.utils.log] INFO: Scrapy 2.13.1 started (bot: scrapybot)
# 2025-05-28 13:23:16 [scrapy.utils.log] INFO: Versions:
# {'lxml': '5.4.0',
#  'libxml2': '2.13.8',
#  'cssselect': '1.3.0',
#  'parsel': '1.10.0',
#  'w3lib': '2.3.1',
#  'Twisted': '24.11.0',
#  'Python': '3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]',
#  'pyOpenSSL': '24.2.1 (OpenSSL 3.3.2 3 Sep 2024)',
#  'cryptography': '43.0.3',
#  'Platform': 'Linux-6.1.123+-x86_64-with-glibc2.35'}
# 2025-05-28 13:23:16 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-05-28 13:23:16 [asyncio] DEBUG: Using selector: EpollSelector
# 2025-05-28 13:23:16 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-05-28 13:23:16 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2025-05-28 13:23:16 [scrapy.extensions.telnet] INFO: Telnet Password: b0ab7df6f5c01976
# ...

# %%
#!scrapy runspider tvbs.py -o tvbs.jl #tvbs

# %%
# import pandas as pd

# # 讀取原始爬蟲結果 JSON Lines 格式檔案
# df = pd.read_json('udn_label.jl', lines=True)

# # 定義關鍵字列表
# keywords = ['通膨', '物價']

# # 新增 label 欄位：如果 content 中有任一關鍵字，標記為 1，否則 0
# df['label'] = df['content'].apply(lambda x: 1 if any(keyword in x for keyword in keywords) else 0)

# # 輸出成 CSV
# df.to_csv('udn_key_labeled.csv', index=False, encoding='utf-8-sig')

# print("成功轉換完成，已輸出為 udn_key_labeled.csv")
# Out:
# <ipython-input-10-78840bb0d212>:4: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json('udn_label.jl', lines=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-78840bb0d212> in <cell line: 0>()
#       2
#       3 # 讀取原始爬蟲結果 JSON Lines 格式檔案
# ----> 4 df = pd.read_json('udn_label.jl', lines=True)
#       5
#       6 # 定義關鍵字列表
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813         return json_reader
#     814     else:
# --> 815         return json_reader.read()
# ...

# %%
# #2. 請寫一程式可以輸入 jsonline檔案，輸出 該檔案內所有新聞標題
# import json
# def read_jsonline(file_path):
#     with open(file_path, "r", encoding="utf-8") as f:
#         for line in f:
#             data = json.loads(line)
#             print(data.get("title", "No Title"))

# if __name__ == "__main__":
#     file_path = "udn.jl"
#     read_jsonline(file_path)
